# %%
import pandas as pd
import numpy as np
import spacy
import re

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Extract the sentences from the text and put the sentences into a list of pandas dataframes
# #### Version 1: segment sentences from entries in set1.csv
# #### Version 2: segment sentences from entries in set2.csv (all the leadership entries)
# #### Version 3: segment sentences in student_responses.csv, then in mentor_responses.csv

# %%
ID = 0
all_sents = []
#all_commas = []

with open("../data/mentor_responses.csv", "r", encoding="utf-8", errors="ignore") as in_file:
    for line in in_file:
        doc = nlp(line)
        sentences = list(doc.sents)
        #commas = re.split(r"[!.?;,]", line[:-9])

        sent_entry = pd.DataFrame()
        #comma_entry = pd.DataFrame()
        
        sent_entry['ID'] = [ID for i in range(len(sentences))]
        sent_entry['PID'] = [str(ID)+'_'+str(i) for i in range(len(sentences))]
        sent_entry['Text'] = [sentences[i] for i in range(len(sentences))]
        
        #comma_entry['ID'] = [ID for i in range(len(commas))]
        #comma_entry['PID'] = [str(ID)+'_'+str(i) for i in range(len(commas))]
        #comma_entry['Text'] = [commas[i] for i in range(len(commas))]
        
        all_sents.append(sent_entry)
        #print(sent_entry)
        #print(all_sents)
        #all_commas.append(comma_entry)
        ID += 1

# %% [markdown]
# ## Concat the list of dataframes into one big table

# %%
big_sents_table = pd.concat(all_sents)
#big_commas_table = pd.concat(all_commas)

# %% [markdown]
# ## Write to a csv file

# %%
big_sents_table.to_csv(path_or_buf="../data/mentor_responses_sentences.csv", index=False)
#big_commas_table.to_csv(path_or_buf="../data/segmented_commas.csv", index=False)

# %% [markdown]
# # SHUFFLE pandas sample

# %%
big_sents_table = big_sents_table.sample(frac=1).reset_index(drop=True)

# %%
big_sents_table
# Out:
#       ID    PID                                               Text
# 0    203  203_0  (", Meagan, has, truly, been, a, leader, ,, no...
# 1    267  267_1  (If, she, has, something, personally, she, wan...
# 2    225  225_1  (He, has, improved, a, lot, on, his, leadershi...
# 3    266  266_2  (She, tended, to, work, alone, ,, and, was, ge...
# 4    156  156_0  (It, 's, difficult, to, identify, an, area, th...
# 5    184  184_0  (Leadership, was, selected, only, because, of,...
# 6    262  262_1  (I, wish, we, could, give, her, more, opportun...
# 7    238  238_0  (", Quanyi, is, advanced, in, all, areas, ,, h...
# 8    305  305_0  (", very, knowledgeable, and, could, be, a, gr...
# 9     32   32_2  (This, is, not, to, say, that, Bradley, has, a...
# 10   156  156_2  (Leadership, was, selected, but, honestly, onl...
# 11   181  181_3  (I, know, that, Kiah, will, accomplish, great,...
# 12    11   11_0  (Alyse, has, incredible, leadership, potential...
# 13   215  215_1  (Once, you, have, established, command, of, a,...
# 14   162  162_0  (James, just, started, to, take, on, a, leader...
# 15    44   44_1  (He, showed, managerial, leadership, even, whe...
# 16   138  138_0  (I, would, like, to, see, Niko, step, up, a, l...
# 17   281  281_3  (Once, again, ,, this, is, partially, our, off...
# 18   302  302_2  (I, would, often, find, he, had, work, complet...
# 19   217  217_0                                           (NA, \n)
# 20   241  241_0  (", Reagan, is, pretty, quiet, and, shy, ,, bu...
# 21   166  166_1               (He, can, be, shy, at, times, ., \n)
# 22   153  153_0  (", Intern, would, benefit, from, more, leader...
# 23   141  141_0  (I, 'm, not, sure, if, this, is, necessarily, ...
# 24   253  253_1  (But, I, think, she, possesses, the, qualities...
# 25   180  180_0  (Leadership, is, an, area, I, have, not, witne...
# 26    77   77_0  (", Emma, shows, tremendous, initiative, and, ...
# 27   222  222_0     (needs, experience, in, leading, a, group, \n)
# 28   250  250_2  (She, is, quick, to, settle, on, a, course, of...
# 29    48   48_1  (He, has, taken, a, technical, lead, role, ,, ...
# ..   ...    ...                                                ...
# 583  100  100_0  (I, believe, as, Allison, gains, more, experie...
# 584   16   16_0  (", As, a, student, intern, ,, I, think, there...
# 585  139  139_0  (", I, would, not, say, that, Derek, struggles...
# 586  234  234_5  (“, go, -, getter, ”, attitude, during, the, i...
# 587  236  236_0  (Patrick, has, worked, well, with, SHPE, and, ...
# 588  261  261_2  (They, learned, study, skills, ,, time, manage...
# 589  244  244_2  (What, she, should, focus, on, when, she, obse...
# 590  302  302_5  (Qing, and, I, have, spoken, about, it, ,, and...
# 591  276  276_1                   (Leadership, is, challenging, .)
# 592   30   30_0  (", Blaine, exceeds, all, expectations, in, th...
# 593   84   84_0  (Gabrielle, did, n't, have, a, lot, of, opport...
# 594  158  158_0  (Jack, excels, already, in, most, other, areas...
# 595  124  124_1  (I, think, that, this, will, come, as, he, gai...
# 596  172  172_1  (This, presented, her, with, some, challenges,...
# 597  210  210_0  (Mr., Mukherjee, is, a, junior, graduate, stud...
# 598  295  295_1  (She, has, great, ideas, ,, and, with, more, l...
# 599  246  246_0               (", Roy, is, hands, down, the, BEST)
# 600  177  177_0  (Kimberly, worked, well, with, her, mentees, i...
# 601  125  125_0  (", I, think, Jordan, can, continue, to, devel...
# 602  277  277_3  (She, needs, to, understand, what, is, being, ...
# 603  263  263_0                   (Shyla, is, a, great, leader, .)
# 604  118  118_1  (I, do, think, she, would, be, a, fine, leader...
# 605  245  245_0  (Robert, could, improve, in, the, area, of, re...
# 606  238  238_1  (This, is, the, only, reason, why, I, would, l...
# 607  146  146_1  (It, is, one, thing, to, work, well, with, oth...
# 608   15   15_0  (Armoni, is, so, used, to, having, to, rely, o...
# 609  268  268_0  (", Student, never, really, stepped, up, as, a...
# 610   43   43_0  (Caroline, 's, greatest, area, for, improvemen...
# 611   91   91_0  (", He, has, very, successfully, taken, the, V...
# 612  313  313_0  (When, addressing, issues, there, are, times, ...
#
# [613 rows x 3 columns]

# %%
big_sents_table.to_csv(path_or_buf="../data/mentor_responses_sentences.csv", index=False)
